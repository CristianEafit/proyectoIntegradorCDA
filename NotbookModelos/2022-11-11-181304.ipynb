# %%
df = [(0,-2),(0,-1),(1,0),(1,1),(3,2)]
df
# Out:
# [(0, -2), (0, -1), (1, 0), (1, 1), (3, 2)]

# %% [markdown]
# $$
# Y = \beta_0 + \beta_1X + \beta_2X^2 + \epsilon
# $$

# %%
import pandas as pd

# %%
type(df)
# Out:
# list

# %%
df1 = pd.DataFrame(df,
                   columns=['Y','X'],
                   index=['1','2','3','4','5'])
df1
# Out:
#    Y  X
# 1  0 -2
# 2  0 -1
# 3  1  0
# 4  1  1
# 5  3  2

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
import patsy
import statsmodels.formula.api as smf

# %%
modelo = smf.ols("Y ~ X", df1)

# %%
resultados = modelo.fit()

# %%
print(resultados.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.817
# Model:                            OLS   Adj. R-squared:                  0.756
# Method:                 Least Squares   F-statistic:                     13.36
# Date:                Sat, 12 Nov 2022   Prob (F-statistic):             0.0354
# Time:                        00:02:23   Log-Likelihood:                -3.3094
# No. Observations:                   5   AIC:                             10.62
# Df Residuals:                       3   BIC:                             9.838
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.0000      0.271      3.693      0.034       0.138       1.862
# ...

# %% [markdown]
# $$
# Y = 1.0000 + 0.7000X + 0.6055
# $$

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(df1['X'].min(),df1['X'].max())
y = 1.0000 + 0.7000*x

# %%
plt.plot(df1['X'],df1['X'],'*',x,y)

# %% [markdown]
# Error del modelo

# %%
y_verdadera = df1['Y']

# %%
y_aproximada = 1 + 0.7000*df1['X']

# %%
SSE = (y_verdadera - y_aproximada) @ (y_verdadera - y_aproximada)
SSE
# Out:
# 1.1

# %%
np.sqrt(SSE/(5-(1+1)))
# Out:
# 0.6055300708194984
